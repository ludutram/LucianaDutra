# %% [markdown]
# <a href="https://colab.research.google.com/github/ludutram/LucianaDutra/blob/master/Medindo_Espa%C3%A7o_de_A%C3%A7%C3%B5es_e_Observa%C3%A7%C3%B5es_Open_AI_Gym.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gym
# !pip install pygame
import pygame

# %% [markdown]
# BOX = Espaço n-dimensional
# Discrete = intervalo fixo de números não negativos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Espaço de observações

# %%
new_step_api=True
env = gym.make('CartPole-v1')
print(env.observation_space)
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)
# /usr/local/lib/python3.7/dist-packages/gym/core.py:318: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."
# /usr/local/lib/python3.7/dist-packages/gym/wrappers/step_api_compatibility.py:40: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
# ...

# %%
print(env.observation_space.low)
# Out:
# [-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38]

# %%
print(env.observation_space.high)
# Out:
# [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38]

# %% [markdown]
# Espaço de Ações

# %%
print(env.action_space)
# Out:
# Discrete(2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(env.action_space.sample())
print(env.action_space.sample())
# Out:
# 0
# 0
